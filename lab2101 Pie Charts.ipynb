# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
df = df.dropna(subset=['DatabaseWantToWorkWith'])

# Split databases and create a new DataFrame
databases = df['DatabaseWantToWorkWith'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('Database')

# Count the occurrences of each database
database_counts = databases.value_counts()

# Get the top 5 databases
top_5_databases = database_counts.head(5)

# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(top_5_databases, labels=top_5_databases.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 5 Databases Respondents Want to Work With')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
df = df.dropna(subset=['DevType'])

# Split developer types and create a new DataFrame
dev_types = df['DevType'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('DevType')

# Count the occurrences of each developer type
dev_type_counts = dev_types.value_counts()

# Get the top 5 developer types
top_5_dev_types = dev_type_counts.head(5)

# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(top_5_dev_types, labels=top_5_dev_types.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 5 Developer Roles')
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
df = df.dropna(subset=['OpSysProfessional'])

# Count the occurrences of each operating system
op_sys_counts = df['OpSysProfessional'].value_counts()

# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(op_sys_counts, labels=op_sys_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Operating Systems Used Professionally')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1770/2328915045.py in ?()
#       3
#       4 df = pd.read_csv("survey-data.csv")
#       5
#       6 # Clean data
# ----> 7 df = df.dropna(subset=['OpSysProfessional'])
#       8
#       9 # Count the occurrences of each operating system
#      10 op_sys_counts = df['OpSysProfessional'].value_counts()
#
# /opt/conda/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# ...

# %%
# there are problem, then check data fields in data frame 
#

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")
print(df.columns)  # Print all column names
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")
df.columns = df.columns.str.strip()  # Strip whitespace from column names
print(df.columns)
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

if 'OpSysProfessional' in df.columns:
    df = df.dropna(subset=['OpSysProfessional'])
    op_sys_counts = df['OpSysProfessional'].value_counts()

    plt.figure(figsize=(10, 10))
    plt.pie(op_sys_counts, labels=op_sys_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title('Operating Systems Used Professionally')
    plt.show()
else:
    print("Column 'OpSysProfessional' not found in the DataFrame.")
# Out:
# Column 'OpSysProfessional' not found in the DataFrame.

# %%
#
# change to column 'OpSysProfessional use'
#
# OpSysProfessional use     
#
if 'OpSysProfessional use' in df.columns:
    df = df.dropna(subset=['OpSysProfessional use'])
    op_sys_counts = df['OpSysProfessional use'].value_counts()

    plt.figure(figsize=(10, 10))
    plt.pie(op_sys_counts, labels=op_sys_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title('Operating Systems Used Professionally')
    plt.show()
else:
    print("Column 'OpSysProfessional use' not found in the DataFrame.")

# %%
#
# change to column 'OpSysPersonal use'    
#
# OpSysPersonal use    
#
if 'OpSysPersonal use' in df.columns:
    df = df.dropna(subset=['OpSysPersonal use'])
    op_sys_counts = df['OpSysPersonal use'].value_counts()

    plt.figure(figsize=(25, 25))
    plt.pie(op_sys_counts, labels=op_sys_counts.index, autopct='%1.1f%%', startangle=90)
    plt.title('Operating Systems Used Professionally')
    plt.show()
else:
    print("Column 'OpSysPersonal use' not found in the DataFrame.")

# %%
type_OpSysProfessional_use = df['OpSysProfessional use'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('OpSysProfessional use')
type_OpSysProfessional_use.head()

# %%
type_OpSysProfessional_use_counts = type_OpSysProfessional_use.value_counts()

type_OpSysProfessional_use_counts

# %%
# Clean data
df = df.dropna(subset=['OpSysProfessional use'])


# Split OpSysProfessional use and create a new DataFrame
OpSys_Professional_use = df['OpSysProfessional use'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('OpSysProfessional use')


# Count the occurrences of each OpProfessional use
OpSys_Professional_use_counts = OpSys_Professional_use.value_counts()

OpSys_Professional_use_counts

# %%
#
#  Will examine the distribution by showing the top 10 OpSysProfessional use in a pie chart.
#

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
if 'OpSysProfessional use' in df.columns:
    df = df.dropna(subset=['OpSysProfessional use'])

    # Count the occurrences of each operating system
    op_sys_counts = df['OpSysProfessional use'].value_counts()

    # Get the top 10 operating systems
    top_10_op_sys = op_sys_counts.head(10)

    # Create pie chart
    plt.figure(figsize=(10, 10))
    plt.pie(top_10_op_sys, labels=top_10_op_sys.index, autopct='%1.1f%%', startangle=90)
    plt.title('Top 10 Operating Systems Used Professionally')
    plt.show()
else:
    print("Column 'OpSysProfessional' not found in the DataFrame.")

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
df = df.dropna(subset=['LanguageHaveWorkedWith'])

# Split languages and create a new DataFrame
languages = df['LanguageHaveWorkedWith'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('Language')

# Count the occurrences of each language
language_counts = languages.value_counts()

# Get the top 5 languages
top_5_languages = language_counts.head(5)

# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(top_5_languages, labels=top_5_languages.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 5 Programming Languages Respondents Have Worked With')
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
df = df.dropna(subset=['NEWCollabToolsHaveWorkedWith'])

# Split collaboration tools and create a new DataFrame
tools = df['NEWCollabToolsHaveWorkedWith'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('Tool')

# Count the occurrences of each tool
tool_counts = tools.value_counts()

# Get the top collaboration tools (e.g., top 5 or top 10)
top_tools = tool_counts.head(5)  # Change head(5) to head(10) for top 10

# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(top_tools, labels=top_tools.index, autopct='%1.1f%%', startangle=90)
plt.title('Top Collaboration Tools Used Professionally')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
df = df.dropna(subset=['LanguageAdmired'])

# Split languages and create a new DataFrame
languages = df['LanguageAdmired'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('Language')

# Count the occurrences of each language
language_counts = languages.value_counts()

# Get the top 5 languages
top_5_languages = language_counts.head(5)

# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(top_5_languages, labels=top_5_languages.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 5 Most Admired Programming Languages')
plt.show()

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here 

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
df = df.dropna(subset=['LanguageAdmired'])

# Split languages and create a new DataFrame
languages = df['LanguageAdmired'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('Language')

# Count the occurrences of each language
language_counts = languages.value_counts()

# Get the top 5 languages
top_5_languages = language_counts.head(5)

# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(top_5_languages, labels=top_5_languages.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 5 Most Admired Programming Languages')
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here 

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
# df = df.dropna(subset=['AIToolCurrently Using'])
# Drop rows with NaN values in the 'AIToolCurrently Using' column
df = df.dropna(subset=['AIToolCurrently Using'])


# Split the 'AIToolCurrently Using' column by ';' and stack the results
tools = df['AIToolCurrently Using'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('Tool')


# Count the occurrences of each tool
tool_counts = tools.value_counts()

# Get the top 5 tools
top_5_tools = tool_counts.head(5)

# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(top_5_tools, labels=top_5_tools.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 5 AI Tools Currently Used by Developers')
plt.show()

# %%
# 3.3 Pie Chart for Preferred Web Frameworks
# The WebframeWantToWorkWith column includes web frameworks 
# that respondents are interested in working with. 
# Visualize the top 5 frameworks in a pie chart.
#

# 3.3 首選 Web 框架圓餅圖 Webframe
# WantToWorkWith 欄位包含受訪者有興趣使用的 Web 架構。以圓餅圖形式直觀顯示前 5 個框架。
#

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
df = df.dropna(subset=['WebframeWantToWorkWith'])

# Split frameworks and create a new DataFrame
frameworks = df['WebframeWantToWorkWith'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('Framework')

# Count the occurrences of each framework
framework_counts = frameworks.value_counts()

# Get the top 5 frameworks
top_5_frameworks = framework_counts.head(5)

# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(top_5_frameworks, labels=top_5_frameworks.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 5 Preferred Web Frameworks')
plt.show()

# %%
# 3.4 Pie Chart for Most Desired Embedded Technologies
# Using the EmbeddedWantToWorkWith column, create a pie chart 
# to show the top 5 most desired embedded technologies that respondents wish to work with.
#
# 3.4 最期望的嵌入式技術圓餅圖 
# 使用 EmbeddedWantToWorkWith 列建立一個圓餅圖，以顯示受訪者最希望使用的 5 大嵌入式技術。
#

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("survey-data.csv")

# Clean data
df = df.dropna(subset=['EmbeddedWantToWorkWith'])

# Split embedded technologies and create a new DataFrame
technologies = df['EmbeddedWantToWorkWith'].str.split(';', expand=True).stack().reset_index(level=1, drop=True).rename('Technology')

# Count the occurrences of each technology
technology_counts = technologies.value_counts()

# Get the top 5 technologies
top_5_technologies = technology_counts.head(5)

# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(top_5_technologies, labels=top_5_technologies.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 5 Most Desired Embedded Technologies')
plt.show()
