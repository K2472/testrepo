# %%
# 
# mod5_final_project, assistment codes
#

# table list:
# CENSUS_DATA
# CHICAGO_PUBLIC_SCHOOLS
# CHICAGO_CRIME_DATA

# %%
# Load the pandas and sqlite3 libraries and establish a connection to FinalDB.db

# %%
# !pip install -q pandas==1.1.5

# %%
import csv, sqlite3

con = sqlite3.connect("FinalDB.db")
cur = con.cursor()

# %%
# Load the SQL magic module

# %%
# %load_ext sql
# %sql sqlite:///FinalDB.db
# Out:
# 'Connected: @FinalDB.db'

# %%
import pandas as padas 

# Chicago Crime Data

df = padas.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01')

# %%
df.head()
# Out:
#          ID CASE_NUMBER        DATE                     BLOCK IUCR  \
# 0   3512276    HK587712  2004-08-28        047XX S KEDZIE AVE  890
# 1   3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE  820
# 2   8002131    HT233595  2011-04-04        043XX S WABASH AVE  820
# 3   7903289    HT133522  2010-12-30      083XX S KINGSTON AVE  840
# 4  10402076    HZ138551  2016-02-02           033XX W 66TH ST  820
#
#   PRIMARY_TYPE                    DESCRIPTION          LOCATION_DESCRIPTION  \
# 0        THEFT                  FROM BUILDING            SMALL RETAIL STORE
# 1        THEFT                 $500 AND UNDER                         OTHER
# 2        THEFT                 $500 AND UNDER  NURSING HOME/RETIREMENT HOME
# 3        THEFT  FINANCIAL ID THEFT: OVER $300                     RESIDENCE
# 4        THEFT                 $500 AND UNDER                         ALLEY
#
#    ARREST  DOMESTIC  ...  DISTRICT  WARD  COMMUNITY_AREA_NUMBER  FBICODE  \
# ...

# %%
# %sql SELECT DISTINCT PRIMARY_TYPE \
from CHICAGO_CRIME_DATA \
where LOCATION_DESCRIPTION like '%SCHOOL%' ;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %%
# %sql desc chicago_public_schools;
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) near "desc": syntax error
# [SQL: desc chicago_public_schools;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
#
# Chicago Public Schools
#
df = pandas.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01')
df.to_sql("CHICAGO_PUBLIC_SCHOOLS",con, if_exists='replace', index=False, method="multi")

# table : CHICAGO_PUBLIC_SCHOOLS
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
df.describe()
# Out:
#            School_ID      ZIP_Code  SAFETY_SCORE  Environment_Score  \
# count     566.000000    566.000000    513.000000         513.000000
# mean   609681.791519  60629.727915     49.504873          47.766082
# std      8831.060946     20.248024     20.110837          16.215584
# min    400018.000000  60605.000000      1.000000           1.000000
# 25%    609873.250000  60618.000000     35.000000          37.000000
# 50%    610052.500000  60625.000000     48.000000          47.000000
# 75%    610212.750000  60639.000000     61.000000          58.000000
# max    610544.000000  60827.000000     99.000000          99.000000
#
#        Instruction_Score  Rate_of_Misconducts__per_100_students_  \
# count         513.000000                              566.000000
# mean           48.288499                               21.085866
# std            17.417176                               27.543835
# min             1.000000                                0.000000
# ...

# %%
# %sql PRAGMA table_info('CHICAGO_PUBLIC_SCHOOLS')
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(0, 'School_ID', 'INTEGER', 0, None, 0),
#  (1, 'NAME_OF_SCHOOL', 'TEXT', 0, None, 0),
#  (2, 'Elementary, Middle, or High School', 'TEXT', 0, None, 0),
#  (3, 'Street_Address', 'TEXT', 0, None, 0),
#  (4, 'City', 'TEXT', 0, None, 0),
#  (5, 'State', 'TEXT', 0, None, 0),
#  (6, 'ZIP_Code', 'INTEGER', 0, None, 0),
#  (7, 'Phone_Number', 'TEXT', 0, None, 0),
#  (8, 'Link', 'TEXT', 0, None, 0),
#  (9, 'Network_Manager', 'TEXT', 0, None, 0),
#  (10, 'Collaborative_Name', 'TEXT', 0, None, 0),
#  (11, 'Adequate_Yearly_Progress_Made_', 'TEXT', 0, None, 0),
#  (12, 'Track_Schedule', 'TEXT', 0, None, 0),
#  (13, 'CPS_Performance_Policy_Status', 'TEXT', 0, None, 0),
#  (14, 'CPS_Performance_Policy_Level', 'TEXT', 0, None, 0),
#  (15, 'HEALTHY_SCHOOL_CERTIFIED', 'TEXT', 0, None, 0),
#  (16, 'Safety_Icon', 'TEXT', 0, None, 0),
#  (17, 'SAFETY_SCORE', 'REAL', 0, None, 0),
#  (18, 'Family_Involvement_Icon', 'TEXT', 0, None, 0),
# ...

# %%
# %sql select Elementary, Middle, or High School from CHICAGO_PUBLIC_SCHOOLS;
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) near "or": syntax error
# [SQL: select Elementary, Middle, or High School from CHICAGO_PUBLIC_SCHOOLS;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %sql select elementary_or_high_school from CHICAGO_PUBLIC_SCHOOLS;
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) no such column: elementary_or_high_school
# [SQL: select elementary_or_high_school from CHICAGO_PUBLIC_SCHOOLS;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %sql SELECT elementary_or_high_school FROM CHICAGO_PUBLIC_SCHOOLS;
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) no such column: elementary_or_high_school
# [SQL: SELECT elementary_or_high_school FROM CHICAGO_PUBLIC_SCHOOLS;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# List all tables
# %sql SELECT name FROM sqlite_master WHERE type='table';

# List all columns in CHICAGO_PUBLIC_SCHOOLS
# %sql PRAGMA table_info(CHICAGO_PUBLIC_SCHOOLS);
# Out:
#  * sqlite:///FinalDB.db
# Done.
#  * sqlite:///FinalDB.db
# Done.
# [(0, 'School_ID', 'INTEGER', 0, None, 0),
#  (1, 'NAME_OF_SCHOOL', 'TEXT', 0, None, 0),
#  (2, 'Elementary, Middle, or High School', 'TEXT', 0, None, 0),
#  (3, 'Street_Address', 'TEXT', 0, None, 0),
#  (4, 'City', 'TEXT', 0, None, 0),
#  (5, 'State', 'TEXT', 0, None, 0),
#  (6, 'ZIP_Code', 'INTEGER', 0, None, 0),
#  (7, 'Phone_Number', 'TEXT', 0, None, 0),
#  (8, 'Link', 'TEXT', 0, None, 0),
#  (9, 'Network_Manager', 'TEXT', 0, None, 0),
#  (10, 'Collaborative_Name', 'TEXT', 0, None, 0),
#  (11, 'Adequate_Yearly_Progress_Made_', 'TEXT', 0, None, 0),
#  (12, 'Track_Schedule', 'TEXT', 0, None, 0),
#  (13, 'CPS_Performance_Policy_Status', 'TEXT', 0, None, 0),
#  (14, 'CPS_Performance_Policy_Level', 'TEXT', 0, None, 0),
#  (15, 'HEALTHY_SCHOOL_CERTIFIED', 'TEXT', 0, None, 0),
#  (16, 'Safety_Icon', 'TEXT', 0, None, 0),
#  (17, 'SAFETY_SCORE', 'REAL', 0, None, 0),
#  (18, 'Family_Involvement_Icon', 'TEXT', 0, None, 0),
# ...

# %%
# Install the IPython SQL extension
# !pip install ipython-sql

# Load the extension
# %load_ext sql

# Connect to the SQLite database
# %sql sqlite:///FinalDB.db

# Verify the connection by listing all tables
# %sql SELECT name FROM sqlite_master WHERE type='table';

# List all columns in the CHICAGO_PUBLIC_SCHOOLS table
# %sql PRAGMA table_info(CHICAGO_PUBLIC_SCHOOLS);

# Execute your query
# %sql SELECT elementary_or_high_school FROM CHICAGO_PUBLIC_SCHOOLS;
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#  * sqlite:///FinalDB.db
# Done.
#  * sqlite:///FinalDB.db
# Done.
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) no such column: elementary_or_high_school
# [SQL: SELECT elementary_or_high_school FROM CHICAGO_PUBLIC_SCHOOLS;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Install the IPython SQL extension if not already installed
# !pip install ipython-sql

# Load the extension
# %load_ext sql

# Connect to the SQLite database
# %sql sqlite:///FinalDB.db

# Execute the query to list the types of schools along with the average safety score for each type
# %sql SELECT "Elementary, Middle, or High School" AS School_Type, AVG(Safety_Score) AS Average_Safety_Score FROM CHICAGO_PUBLIC_SCHOOLS GROUP BY "Elementary, Middle, or High School";
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#  * sqlite:///FinalDB.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %%
#
# 
# %sql PRAGMA table_info(CHICAGO_CRIME_DATA);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(0, 'ID', 'INTEGER', 0, None, 0),
#  (1, 'CASE_NUMBER', 'TEXT', 0, None, 0),
#  (2, 'DATE', 'TEXT', 0, None, 0),
#  (3, 'BLOCK', 'TEXT', 0, None, 0),
#  (4, 'IUCR', 'TEXT', 0, None, 0),
#  (5, 'PRIMARY_TYPE', 'TEXT', 0, None, 0),
#  (6, 'DESCRIPTION', 'TEXT', 0, None, 0),
#  (7, 'LOCATION_DESCRIPTION', 'TEXT', 0, None, 0),
#  (8, 'ARREST', 'INTEGER', 0, None, 0),
#  (9, 'DOMESTIC', 'INTEGER', 0, None, 0),
#  (10, 'BEAT', 'INTEGER', 0, None, 0),
#  (11, 'DISTRICT', 'INTEGER', 0, None, 0),
#  (12, 'WARD', 'REAL', 0, None, 0),
#  (13, 'COMMUNITY_AREA_NUMBER', 'REAL', 0, None, 0),
#  (14, 'FBICODE', 'TEXT', 0, None, 0),
#  (15, 'X_COORDINATE', 'REAL', 0, None, 0),
#  (16, 'Y_COORDINATE', 'REAL', 0, None, 0),
#  (17, 'YEAR', 'INTEGER', 0, None, 0),
#  (18, 'LATITUDE', 'REAL', 0, None, 0),
#  (19, 'LONGITUDE', 'REAL', 0, None, 0),
#  (20, 'LOCATION', 'TEXT', 0, None, 0)]

# %%
#
# 
# %sql PRAGMA table_info(CENSUS_DATA);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(0, 'COMMUNITY_AREA_NUMBER', 'REAL', 0, None, 0),
#  (1, 'COMMUNITY_AREA_NAME', 'TEXT', 0, None, 0),
#  (2, 'PERCENT_OF_HOUSING_CROWDED', 'REAL', 0, None, 0),
#  (3, 'PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'REAL', 0, None, 0),
#  (4, 'PERCENT_AGED_16__UNEMPLOYED', 'REAL', 0, None, 0),
#  (5, 'PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'REAL', 0, None, 0),
#  (6, 'PERCENT_AGED_UNDER_18_OR_OVER_64', 'REAL', 0, None, 0),
#  (7, 'PER_CAPITA_INCOME', 'INTEGER', 0, None, 0),
#  (8, 'HARDSHIP_INDEX', 'REAL', 0, None, 0)]

# %%
# %sql select * from census_data limit 6;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0),
#  (6.0, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17.0, 60058, 5.0)]

# %%
# %sql select COMMUNITY_AREA_NAME, percent_households_below_poverty from census_data \
order by percent_households_below_poverty desc limit 5
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %%
# 8. Which community area is most crime prone? Display the coumminty area number only
#

# COMMUNITY_AREA_NUMBER
# %sql select * from chicago_crime_data limit 5
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(3512276, 'HK587712', '2004-08-28', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 0, 0, 911, 9, 14.0, 58.0, '6', 1155838.0, 1873050.0, 2004, 41.807440500000006, -87.70395585, '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '2004-06-26', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 0, 0, 1112, 11, 27.0, 23.0, '6', 1152206.0, 1906127.0, 2004, 41.89827996, -87.71640551, '(41.898279962, -87.716405505)'),
#  (8002131, 'HT233595', '2011-04-04', '043XX S WABASH AVE', '820', 'THEFT', '$500 AND UNDER', 'NURSING HOME/RETIREMENT HOME', 0, 0, 221, 2, 3.0, 38.0, '6', 1177436.0, 1876313.0, 2011, 41.81593313, -87.62464213, '(41.815933131, -87.624642127)'),
#  (7903289, 'HT133522', '2010-12-30', '083XX S KINGSTON AVE', '840', 'THEFT', 'FINANCIAL ID THEFT: OVER $300', 'RESIDENCE', 0, 0, 423, 4, 7.0, 46.0, '6', 1194622.0, 1850125.0, 2010, 41.74366532, -87.56246276, '(41.743665322, -87.562462756)'),
# ...

# %%
# %sql select \
district, community_area \
from chicago_crime_data
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) no such column: community_area
# [SQL: select  district, community_area  from chicago_crime_data]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
