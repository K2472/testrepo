# %%
# Connect to the database.

import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %%
# Import pandas module.

import pandas as pd

# %%
QUERY = """
SELECT *
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)

# %%
df.to_csv('master_data.csv', index=False, sep=',', encoding='utf-8')

# %%
# Demo: How to run an sql query
#

# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %%
# Demo: How to run a group by query¶
#

QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %%
# Demo: How to describe a table
#

table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %%
QUERY = """
SELECT * 
FROM master
"""
df_db = pd.read_sql_query(QUERY,conn)
df_db.describe()
# Out:
#               index    Respondent     CompTotal  ConvertedComp   WorkWeekHrs  \
# count  11398.000000  11398.000000  1.058900e+04   1.058200e+04  11276.000000
# mean    5698.500000  12490.392437  7.570477e+05   1.315967e+05     42.064606
# std     3290.463519   7235.461999  9.705598e+06   2.947865e+05     24.672741
# min        0.000000      4.000000  0.000000e+00   0.000000e+00      3.000000
# 25%     2849.250000   6264.250000  2.500000e+04   2.686800e+04     40.000000
# 50%     5698.500000  12484.000000  6.500000e+04   5.774500e+04     40.000000
# 75%     8547.750000  18784.750000  1.200000e+05   1.000000e+05     43.000000
# max    11397.000000  25142.000000  7.000000e+08   2.000000e+06   1012.000000
#
#         CodeRevHrs           Age
# count  8972.000000  11111.000000
# mean      4.781071     30.779318
# std       4.567060      7.393680
# min       0.000000     16.000000
# 25%       2.000000     25.000000
# 50%       4.000000     29.000000
# 75%       5.000000     35.000000
# ...

# %%
df_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           11398 non-null  int64
#  1   Respondent      11398 non-null  int64
#  2   MainBranch      11398 non-null  object
#  3   Hobbyist        11398 non-null  object
#  4   OpenSourcer     11398 non-null  object
#  5   OpenSource      11317 non-null  object
#  6   Employment      11398 non-null  object
#  7   Country         11398 non-null  object
#  8   Student         11347 non-null  object
#  9   EdLevel         11286 non-null  object
#  10  UndergradMajor  10661 non-null  object
#  11  OrgSize         11302 non-null  object
#  12  YearsCode       11389 non-null  object
#  13  Age1stCode      11385 non-null  object
#  14  YearsCodePro    11382 non-null  object
#  15  CareerSat       11398 non-null  object
#  16  JobSat          11397 non-null  object
# ...

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.12.2

# %%
# !pip install seaborn --upgrade

# %%
# Hands-on Lab
# Visualizing distribution of data
#
# 可視化數據分佈

# %%
# Histograms
# Plot a histogram of ConvertedComp.

# 直方圖 
# 繪製 ConvertedComp 的直方圖。

# %%
# your code goes here
import seaborn as sns

QUERY = """
SELECT ConvertedComp
FROM master
"""
df = pd.read_sql_query(QUERY,conn)
ax = sns.histplot(df['ConvertedComp'])

# %%
# Demo: How to list all tables
#

# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %%
import seaborn as sns
QUERY = """SELECT ConvertedComp FROM master"""
df = pd.read_sql_query(QUERY, conn)
ax = sns.histplot(df['ConvertedComp'])

# %%
# %pip install seaborn
#

# %%
import seaborn as sns
print(sns.__version__)

# !pip install seaborn --upgrade
import matplotlib.pyplot as plt
# Out:
# 0.12.2
# ...

# %%
# 
# 
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with a 'ConvertedComp' column

# Create a histogram
sns.histplot(df['ConvertedComp'], bins=30, kde=True)

# Customize the plot (optional)
plt.title('Histogram of Converted Compensation')
plt.xlabel('Converted Compensation')
plt.ylabel('Frequency')

plt.show()

# %%
# Box Plots
# Plot a box plot of Age.
#
# 箱線圖 繪製年齡的箱型圖。
#

# %%
QUERY = """SELECT ConvertedComp FROM master"""
df = pd.read_sql_query(QUERY, conn)
df.head()
# Out:
#    ConvertedComp
# 0        61000.0
# 1        95179.0
# 2        90000.0
# 3       455352.0
# 4        65277.0

# %%
# 
# To defined a DataFrame named 'df' with an 'Age' column
# has been defined below from query, that retrieve data from master
#
QUERY = """
SELECT Respondent, Age
FROM master
"""
df = pd.read_sql_query(QUERY,conn)

df['Age'].describe()
# Out:
# count    11111.000000
# mean        30.779318
# std          7.393680
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with an 'Age' column

# Create a box plot
sns.boxplot(x=df['Age'])

# Customize the plot (optional)
plt.title('Box Plot of Age')
plt.xlabel('Age')

plt.show()

# %%
# Box Plots
# Plot a box plot of Age.
#
# 箱線圖
# 繪製年齡的箱型圖。
#

QUERY = """
SELECT Respondent, Age
FROM master
"""
df_Age = pd.read_sql_query(QUERY,conn)

df_Age['Age'].describe()
# Out:
# count    11111.000000
# mean        30.779318
# std          7.393680
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
df_Age['Age'].plot(kind='box', figsize=(10, 7))

plt.title("Box plots of Respondent's Age")
plt.ylabel('Interval Age')

plt.show()

# %%
# 
# case 2
# 
# 箱線圖
# 繪製年齡的箱型圖。

# your code goes here
QUERY = """
SELECT Age
FROM master
"""
df_Age = pd.read_sql_query(QUERY, conn)
ax = sns.boxplot(x=df_Age['Age'])

# %%
# Visualizing relationships in data
# Scatter Plots
# Create a scatter plot of Age and WorkWeekHrs.
#
# 可視化數據中的關係
# 散點圖
# 建立 Age 和 WorkWeekHrs 的散佈圖。

# %%
# your code goes here

QUERY = """
SELECT Age, WorkWeekHrs
FROM master
"""
df_corr = pd.read_sql_query(QUERY,conn)

df_corr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          11111 non-null  float64
#  1   WorkWeekHrs  11276 non-null  float64
# dtypes: float64(2)
# memory usage: 178.2 KB

# %%
df_corr.corr()
# Out:
#                   Age  WorkWeekHrs
# Age          1.000000     0.036517
# WorkWeekHrs  0.036517     1.000000

# %%
df_corr.plot(kind='scatter', x='Age', y='WorkWeekHrs', figsize=(10,6), color='darkblue')

plt.title('Relation Between Age and Work Week Hours of Respondents')
plt.xlabel('Age')
plt.ylabel('Work Week Hours')

plt.show()

# %%
# Visualizing relationships in data
# Scatter Plots
# Create a scatter plot of Age and WorkWeekHrs.
#
# 可視化數據中的關係
# 散點圖
# 建立 Age 和 WorkWeekHrs 的散佈圖。
#
# case 2

# %%
# your code goes here
QUERY = """
SELECT Age, WorkWeekHrs
FROM master
"""
df = pd.read_sql_query(QUERY, conn)
ax = sns.scatterplot(data=df, x='Age', y='WorkWeekHrs')

# %%
# Bubble Plots
# Create a bubble plot of WorkWeekHrs and CodeRevHrs, use Age column as bubble size.
#
# 氣泡圖
# 建立 WorkWeekHrs 和 CodeRevHrs 的氣泡圖，使用 Age 列作為氣泡大小。
#

# %%
QUERY = """
SELECT CodeRevHrs, WorkWeekHrs, Age
FROM master
"""
df_bubble = pd.read_sql_query(QUERY,conn)

df_bubble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CodeRevHrs   8972 non-null   float64
#  1   WorkWeekHrs  11276 non-null  float64
#  2   Age          11111 non-null  float64
# dtypes: float64(3)
# memory usage: 267.3 KB

# %%
# normalize Age data
norm_Age = (df_bubble['Age'] - df_bubble['Age'].min()) / (df_bubble['Age'].max() - df_bubble['Age'].min())

# %%
norm_Age
# Out:
# 0        0.072289
# 1        0.084337
# 2        0.144578
# 3        0.120482
# 4        0.156627
#            ...
# 11393    0.240964
# 11394    0.108434
# 11395    0.216867
# 11396    0.108434
# 11397    0.168675
# Name: Age, Length: 11398, dtype: float64

# %%
df_bubble.plot(kind='scatter',
               x='WorkWeekHrs',
               y='CodeRevHrs',
               figsize=(14, 8),
               alpha=0.5,  # transparency
               color='green',
               s=norm_Age * 1000 + 10,  # pass in weights 
               )

plt.title('Relation Between WorkWeekHrs and CodeRevHrs of Respondents')
plt.xlabel('WorkWeekHrs')
plt.ylabel('CodeRevHrs')
plt.legend(['Age'], loc='upper right', fontsize='x-large')

plt.show()

# %%
# Bubble Plots
# Create a bubble plot of WorkWeekHrs and CodeRevHrs, use Age column as bubble size.
#
# 氣泡圖
# 建立 WorkWeekHrs 和 CodeRevHrs 的氣泡圖，使用 Age 列作為氣泡大小。
#
# case 2

# %%
# your code goes here
QUERY = """
SELECT Age, WorkWeekHrs, CodeRevHrs
FROM master
"""
df = pd.read_sql_query(QUERY, conn)
ax = sns.scatterplot(data=df, x='WorkWeekHrs', y='CodeRevHrs', size='Age', hue='Age', sizes=(20,200))

# data=df：指定用於繪圖的 DataFrame。	
# x='WorkWeekHrs'：將 WorkWeekHrs 欄位設定為 x 軸變數。	
# y='CodeRevHrs'：將 CodeRevHrs 欄位設定為 y 軸變數。	
# size='Age'：根據 Age 欄位設定資料點的大小。年齡值越大，得分也越大。	
# Hue='Age'：根據年齡列設定資料點的顏色。這將為不同年齡組創建不同的色點。	
# size=(20,200)：指定點的最小和最大尺寸，確保點可見且可區分。	
# 產生的散佈圖將視覺化每週工作時數 (WorkWeekHrs) 與程式碼審查時數 (CodeRevHrs) 之間的關係。
# 每個點的大小和顏色將代表個人的年齡，使您可以探索這些變數與年齡之間的潛在相關性。

# %%
QUERY = """
SELECT Age, ConvertedComp
FROM master
WHERE Age >= 30 AND Age <= 35
"""
df = pd.read_sql_query(QUERY, conn)
ax = sns.scatterplot(data=df, x='Age', y='ConvertedComp', size='Age', hue='Age', sizes=(20,200))

# %%
#
# Visualizing composition of data
# Pie Charts
#
# Create a pie chart of the top 5 databases that respondents wish to learn next year. 
# Label the pie chart with database names. Display percentages of each database on the pie chart.
#
# 
# 可視化數據的組成
# 圓餅圖
#
# 建立一個圓餅圖，列出受訪者明年希望學習的前 5 個資料庫。使用資料庫名稱標記餅圖。在圓餅圖上顯示每個資料庫的百分比。
#

# %%
QUERY = """
SELECT * 
FROM DatabaseDesireNextYear
"""
df_db = pd.read_sql_query(QUERY,conn)
df_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29575 entries, 0 to 29574
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              29575 non-null  int64
#  1   DatabaseDesireNextYear  29575 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 462.2+ KB

# %%
df_db.describe()
# Out:
#          Respondent
# count  29575.000000
# mean   12471.108470
# std     7228.329502
# min        4.000000
# 25%     6245.500000
# 50%    12443.000000
# 75%    18819.000000
# max    25142.000000

# %%
# 解釋：
#
# 取得排名前 5 的資料庫：
#
# top_5_databases = df['DatabaseDesireNextYear'].value_counts().head(5)：
# 此行統計「DatabaseDesireNextYear」欄位中每個資料庫的出現次數，並選擇前 5 個最常見的資料庫。
# 創建圓餅圖：
#
# plt.pie(top_5_databases, labels=top_5_databases.index, autopct='%1.1f%%'):
# top_5_databases：提供每個餅圖切片的數值。
# labels=top_5_databases.index：設定每個切片的標籤，即資料庫名稱。
# autopct='%1.1f%%'：顯示每個切片的百分比，保留一位小數。
# 新增標題：
# 
# plt.title('Top 5 Databases to Learn Next Year')：設定餅圖的標題。
# 顯示情節：
#
# plt.show()：顯示已建立的圓餅圖。
# 此程式碼將產生一個圓餅圖，直觀地顯示受訪者明年希望學習的前 5 個資料庫及其各自的百分比。

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df' with a column 'DatabaseDesireNextYear'
QUERY = """
SELECT * 
FROM DatabaseDesireNextYear
"""
df_db = pd.read_sql_query(QUERY,conn)
df = df_db

# Get the top 5 most desired databases
top_5_databases = df['DatabaseDesireNextYear'].value_counts().head(5)

# Create a pie chart
plt.pie(top_5_databases, labels=top_5_databases.index, autopct='%1.1f%%')
plt.title('Top 5 Databases to Learn Next Year')
plt.show()

# %%
#
# Visualizing composition of data
# Pie Charts
#
# Create a pie chart of the top 5 databases that respondents wish to learn next year. 
# Label the pie chart with database names. Display percentages of each database on the pie chart.
#
# 
# 可視化數據的組成
# 圓餅圖
#
# 建立一個圓餅圖，列出受訪者明年希望學習的前 5 個資料庫。使用資料庫名稱標記餅圖。在圓餅圖上顯示每個資料庫的百分比。
#
# case 2

# %%
QUERY = """
SELECT * 
FROM DatabaseDesireNextYear
"""
df_db = pd.read_sql_query(QUERY,conn)

df_db.head()
# Out:
#    Respondent DatabaseDesireNextYear
# 0           4                  MySQL
# 1           4                 SQLite
# 2           9             PostgreSQL
# 3           9                  Redis
# 4           9                 SQLite

# %%
# group respondents by database and apply count() function 
df_groupby = df_db.groupby('DatabaseDesireNextYear', axis=0).count()

df_groupby.sort_values(["Respondent"], ascending=False, inplace=True)

# %%
df_pie = df_groupby.head()
df_pie
# Out:
#                         Respondent
# DatabaseDesireNextYear
# PostgreSQL                    4328
# MongoDB                       3649
# Redis                         3331
# MySQL                         3281
# Elasticsearch                 2856

# %%
# autopct create %, start angle represent starting point
df_pie['Respondent'].plot(kind='pie',
                          figsize=(5, 6),
                          autopct='%1.1f%%', # add in percentages
                          startangle=90,     # start angle 90°
                          shadow=True,       # add shadow      
                          )

plt.title('Top 5 Databases that Respondents Wish to Learn Next Year')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %%
QUERY = """
SELECT LanguageDesireNextYear, count(*) as c1
FROM LanguageDesireNextYear
group by LanguageDesireNextYear
order by c1 DESC
"""
df = pd.read_sql_query(QUERY, conn)
df.head()
# Out:
#   LanguageDesireNextYear    c1
# 0             JavaScript  6630
# 1               HTML/CSS  5328
# 2                 Python  5239
# 3                    SQL  5012
# 4             TypeScript  4088

# %%
QUERY = """
SELECT LanguageWorkedWith, count(*) as c1
FROM LanguageWorkedWith
group by LanguageWorkedWith
order by c1 DESC
"""
df = pd.read_sql_query(QUERY, conn)
df.head()
# Out:
#       LanguageWorkedWith    c1
# 0             JavaScript  8687
# 1               HTML/CSS  7830
# 2                    SQL  7106
# 3  Bash/Shell/PowerShell  4642
# 4                 Python  4542

# %%
QUERY = """
SELECT * 
FROM LanguageWorkedWith
"""
df_lg = pd.read_sql_query(QUERY,conn)

df_lg.head()
# Out:
#    Respondent LanguageWorkedWith
# 0           4                  C
# 1           4                C++
# 2           4                 C#
# 3           4             Python
# 4           4                SQL

# %%
# group respondents by language and apply count() function 
df_lg = df_lg.groupby('LanguageWorkedWith', axis=0).count()

df_lg.sort_values(["Respondent"], ascending=False, inplace=True)

# %%
df_lg.head()
# Out:
#                        Respondent
# LanguageWorkedWith
# JavaScript                   8687
# HTML/CSS                     7830
# SQL                          7106
# Bash/Shell/PowerShell        4642
# Python                       4542

# %%
df_lg
# Out:
#                        Respondent
# LanguageWorkedWith
# JavaScript                   8687
# HTML/CSS                     7830
# SQL                          7106
# Bash/Shell/PowerShell        4642
# Python                       4542
# Java                         4506
# C#                           4288
# TypeScript                   3232
# PHP                          2913
# C++                          1946
# C                            1578
# Ruby                         1149
# Go                           1114
# Other(s):                     840
# Kotlin                        751
# Swift                         707
# VBA                           628
# R                             585
# Objective-C                   518
# Scala                         492
# Assembly                      437
# Rust                          324
# Dart                          237
# Elixir                        187
# Clojure                       164
# F#                            158
# ...

# %%
df_pie = df_lg.head()

# %%
# autopct create %, start angle represent starting point
df_pie['Respondent'].plot(kind='pie',
                          figsize=(5, 6),
                          autopct='%1.1f%%', # add in percentages
                          startangle=90,     # start angle 90°
                          shadow=True,       # add shadow      
                          )

plt.title('Top 5 Languages that Respondents Wish to Learn Next Year')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %%
QUERY = """
SELECT LanguageWorkedWith, count(*) as c1
FROM LanguageWorkedWith
group by LanguageWorkedWith
order by c1 DESC
"""
df = pd.read_sql_query(QUERY, conn)
df.head()
# Out:
#       LanguageWorkedWith    c1
# 0             JavaScript  8687
# 1               HTML/CSS  7830
# 2                    SQL  7106
# 3  Bash/Shell/PowerShell  4642
# 4                 Python  4542

# %%
df
# Out:
#        LanguageWorkedWith    c1
# 0              JavaScript  8687
# 1                HTML/CSS  7830
# 2                     SQL  7106
# 3   Bash/Shell/PowerShell  4642
# 4                  Python  4542
# 5                    Java  4506
# 6                      C#  4288
# 7              TypeScript  3232
# 8                     PHP  2913
# 9                     C++  1946
# 10                      C  1578
# 11                   Ruby  1149
# 12                     Go  1114
# 13              Other(s):   840
# 14                 Kotlin   751
# 15                  Swift   707
# 16                    VBA   628
# 17                      R   585
# 18            Objective-C   518
# 19                  Scala   492
# 20               Assembly   437
# 21                   Rust   324
# 22                   Dart   237
# 23                 Elixir   187
# 24                Clojure   164
# 25                     F#   158
# 26            WebAssembly   133
# 27                 Erlang    98

# %%
df['LanguageWorkedWith'].head()
# Out:
# 0               JavaScript
# 1                 HTML/CSS
# 2                      SQL
# 3    Bash/Shell/PowerShell
# 4                   Python
# Name: LanguageWorkedWith, dtype: object

# %%
df['LanguageWorkedWith'].count()
# Out:
# 28

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame `df` with a column 'LanguageDesireNextYear'

# Get the top 5 most desired languages
# top_5_languages = df['LanguageDesireNextYear'].value_counts().head(5)
top_5_languages = df['LanguageWorkedWith'].value_counts().head(5)
# top_5_languages = df.c1.head(5)

# Create a pie chart
plt.pie(top_5_languages, labels=top_5_languages.index, autopct='%1.1f%%')
plt.title('Top 5 Programming Languages to Learn Next Year')
plt.show()

# %%
# Question 3
# How many respondents indicated that they currently work with 'SQL'? 
#
# 問題3 有多少受訪者表示目前使用「SQL」？

# %%
# your code goes here

QUERY = """
SELECT *, COUNT(*) AS count
FROM LanguageWorkedWith
GROUP BY LanguageWorkedWith
ORDER BY count DESC
LIMIT 5

"""
df = pd.read_sql_query(QUERY,conn)

print(df)

data = df['count']
labels = df['LanguageWorkedWith']

plt.rcParams['figure.figsize'] = [8,8]

fig, ax = plt.subplots()
ax.pie(data, labels = labels, autopct='%1.1f%%', explode = (0, 0.1, 0, 0, 0), shadow = True)
plt.show()
# Out:
#    Respondent     LanguageWorkedWith  count
# 0           9             JavaScript   8687
# 1           9               HTML/CSS   7830
# 2           4                    SQL   7106
# 3           9  Bash/Shell/PowerShell   4642
# 4           4                 Python   4542

# %%
QUERY = """
SELECT * 
FROM DatabaseWorkedWith
"""
df_db = pd.read_sql_query(QUERY,conn)

df_db.info
# Out:
# <bound method DataFrame.info of        Respondent    DatabaseWorkedWith
# 0               4                 MySQL
# 1               4                SQLite
# 2               9              DynamoDB
# 3               9            PostgreSQL
# 4               9                SQLite
# ...           ...                   ...
# 31370       25137                 MySQL
# 31371       25138            PostgreSQL
# 31372       25141  Microsoft SQL Server
# 31373       25141                 Redis
# 31374       25142            PostgreSQL
#
# [31375 rows x 2 columns]>

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with a 'DatabaseWorkedWith' column
df = df_db

# Filter the DataFrame for respondents who work with SQL
sql_users = df[df['DatabaseWorkedWith'].str.contains('SQL')]

# Count the number of respondents
num_sql_users = sql_users.shape[0]

print("Number of respondents working with SQL:", num_sql_users)
# Out:
# Number of respondents working with SQL: 16924

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with a 'DatabaseWorkedWith' column

# Filter the DataFrame for respondents who work with SQL
sql_users = df[df['DatabaseWorkedWith'].str.contains('SQL')]

# Count the number of respondents
num_sql_users = sql_users.shape[0]

print("Number of respondents working with SQL:", num_sql_users)
# Out:
# Number of respondents working with SQL: 16924

# %%
# Question 4
# How many respondents indicated that they work on 'MySQL' only? 
#
# 問題4 有多少受訪者表示他們只使用「MySQL」？

# %%
QUERY = """
SELECT * 
FROM DatabaseWorkedWith
"""
df_db = pd.read_sql_query(QUERY,conn)

df_db.info()
df_db.columns
df_db.count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31375 entries, 0 to 31374
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Respondent          31375 non-null  int64
#  1   DatabaseWorkedWith  31375 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 490.4+ KB
# <bound method DataFrame.count of        Respondent    DatabaseWorkedWith
# 0               4                 MySQL
# 1               4                SQLite
# 2               9              DynamoDB
# 3               9            PostgreSQL
# 4               9                SQLite
# ...           ...                   ...
# 31370       25137                 MySQL
# 31371       25138            PostgreSQL
# 31372       25141  Microsoft SQL Server
# 31373       25141                 Redis
# 31374       25142            PostgreSQL
#
# [31375 rows x 2 columns]>

# %%
df = df_db
df.head()
# Out:
#    Respondent DatabaseWorkedWith
# 0           4              MySQL
# 1           4             SQLite
# 2           9           DynamoDB
# 3           9         PostgreSQL
# 4           9             SQLite

# %%
# Assuming you have a DataFrame named 'df' with a 'DatabaseWorkedWith' column

# Filter the DataFrame for respondents who only work with MySQL
mysql_only_respondents = df[df['DatabaseWorkedWith'] == 'MySQL']

# Count the number of respondents
num_mysql_only = mysql_only_respondents.shape[0]

print("Number of respondents working on MySQL only:", num_mysql_only)
# Out:
# Number of respondents working on MySQL only: 5469

# %%
QUERY = """
SELECT DatabaseWorkedWith, count(*) as cnt
FROM DatabaseWorkedWith
group by DatabaseWorkedWith
order by cnt DESC
"""
df_db = pd.read_sql_query(QUERY,conn)
df_db
# Out:
#       DatabaseWorkedWith   cnt
# 0                  MySQL  5469
# 1   Microsoft SQL Server  4110
# 2             PostgreSQL  4097
# 3                 SQLite  3248
# 4                MongoDB  3016
# 5                  Redis  2508
# 6          Elasticsearch  1954
# 7                 Oracle  1744
# 8                MariaDB  1709
# 9               Firebase  1314
# 10              DynamoDB   831
# 11             Other(s):   728
# 12             Cassandra   397
# 13             Couchbase   250

# %%
#
# Visualizing composition of data
# Pie Charts
#
# Create a pie chart of the top 5 databases that respondents wish to learn next year. 
# Label the pie chart with database names. Display percentages of each database on the pie chart.
#
# 
# 可視化數據的組成
# 圓餅圖
#
# 建立一個圓餅圖，列出受訪者明年希望學習的前 5 個資料庫。使用資料庫名稱標記餅圖。在圓餅圖上顯示每個資料庫的百分比。
#

# %%
# Hands-on Lab 19: Stacked Charts
# 
# Stacked Charts
# Create a stacked chart of median WorkWeekHrs and CodeRevHrs for the age group 30 to 35.
#
# 堆積圖表
# 建立 30 至 35 歲年齡組的中位數 WorkWeekHrs 和 CodeRevHrs 堆積圖。
#

# %%
# your code goes here

QUERY = """
SELECT CodeRevHrs, WorkWeekHrs, Age
FROM master
"""
df_stacked = pd.read_sql_query(QUERY,conn)

df_stacked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CodeRevHrs   8972 non-null   float64
#  1   WorkWeekHrs  11276 non-null  float64
#  2   Age          11111 non-null  float64
# dtypes: float64(3)
# memory usage: 267.3 KB

# %%
df_stacked = df_stacked.loc[(df_stacked['Age'] >= 30) & (df_stacked['Age'] <= 35)].reset_index().drop(columns=['index'])
df_stacked
# Out:
#       CodeRevHrs  WorkWeekHrs   Age
# 0            3.0          8.0  31.0
# 1            2.0         40.0  34.0
# 2            2.0         40.0  32.0
# 3           15.0         42.0  34.0
# 4            2.0         40.0  33.0
# ...          ...          ...   ...
# 2937         4.0         42.0  32.0
# 2938         2.0         50.0  32.0
# 2939        14.0         56.0  32.0
# 2940         5.0         40.0  34.0
# 2941         1.0         80.0  30.0
#
# [2942 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
df_stacked.groupby(['CodeRevHrs','Age'])['WorkWeekHrs'].median().sort_values(ascending=False).unstack().plot(kind='bar', stacked=True, figsize=(25, 10))
plt.title('Stacked Chart of Median WorkWeekHrs and CodeRevHrs For The Age Group 30 to 35',
          loc='center',pad=30, fontsize=30, color='blue')
plt.xlabel('CodeRevHrs', fontsize = 20)
plt.ylabel('WorkWeekHrs', fontsize = 20)
plt.legend(bbox_to_anchor=(1, 1), shadow=True, ncol=1, title='Age')
plt.ylim(ymin=0)
labels, locations = plt.yticks()
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Hands-on Lab 19: Stacked Charts
# 
# Stacked Charts
# Create a stacked chart of median WorkWeekHrs and CodeRevHrs for the age group 30 to 35.
#
# 堆積圖表
# 建立 30 至 35 歲年齡組的中位數 WorkWeekHrs 和 CodeRevHrs 堆積圖。
#
# case 2
#

# %%
QUERY = """
SELECT CodeRevHrs, WorkWeekHrs, Age
FROM master
"""
df_stacked = pd.read_sql_query(QUERY,conn)

df_stacked.info()
df = df_stacked
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CodeRevHrs   8972 non-null   float64
#  1   WorkWeekHrs  11276 non-null  float64
#  2   Age          11111 non-null  float64
# dtypes: float64(3)
# memory usage: 267.3 KB

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have a DataFrame 'df' with 'Age', 'WorkWeekHrs', and 'CodeRevHrs' columns

# Filter data for the age group 30 to 35
df_filtered = df[(df['Age'] >= 30) & (df['Age'] <= 35)]

# Group data by 'Age' and calculate median WorkWeekHrs and CodeRevHrs
grouped_data = df_filtered.groupby('Age')[['WorkWeekHrs', 'CodeRevHrs']].median()

# Create a stacked bar chart
grouped_data.plot(kind='bar', stacked=True)

# Customize the plot
plt.title('Median WorkWeekHrs and CodeRevHrs for Age Group 30-35')
plt.xlabel('Age Group')
plt.ylabel('Hours')

plt.show()

# %%
# Hands-on Lab 19: Stacked Charts
# 
# Stacked Charts
# Create a stacked chart of median WorkWeekHrs and CodeRevHrs for the age group 30 to 35.
#
# 堆積圖表
# 建立 30 至 35 歲年齡組的中位數 WorkWeekHrs 和 CodeRevHrs 堆積圖。
#
# case 3
#

# %%
# your code goes here
import matplotlib.pyplot as plt
# %matplotlib inline

QUERY = """
SELECT WorkWeekHrs, CodeRevHrs, Age
FROM master
WHERE age <= 35 AND age >= 30
order by age
"""

df = pd.read_sql_query(QUERY, conn)

l1 = [30,31,32,33,34,35]
l2 = []
l3 = []

for i in l1:
    l2.append(df[df['Age']==i]['WorkWeekHrs'].median())
    l3.append(df[df['Age']==i]['CodeRevHrs'].median())

# Chart
labels = l1
y1 = l2
y2 = l3

plt.bar(labels, y1, color='r')
plt.bar(labels, y2, bottom=y1, color='b')
plt.legend(['WorkWeekHrs', 'CodeRevHrs'])
plt.xlabel('Age')
plt.ylabel('Hours')
plt.title('WorkWeek hours & CodeRevHrs')
plt.show()

# %%
# Visualizing comparison of data
#
# Line Chart¶
# Plot the median ConvertedComp for all ages from 45 to 60.
#
# 數據比較視覺化
# 折線圖
# 繪製 45 歲至 60 歲所有年齡層的 ConvertedComp 中位數。
#

# %%
# your code goes here

QUERY = """
SELECT ConvertedComp, Age
FROM master
"""
df_line = pd.read_sql_query(QUERY,conn)

df_line.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ConvertedComp  10582 non-null  float64
#  1   Age            11111 non-null  float64
# dtypes: float64(2)
# memory usage: 178.2 KB

# %%
df_line = df_line.loc[(df_line['Age'] >= 25) & (df_line['Age'] <= 30)].reset_index().drop(columns=['index'])
df_line.dropna(inplace=True)
df_line
# Out:
#       ConvertedComp   Age
# 0           90000.0  28.0
# 1          455352.0  26.0
# 2           65277.0  29.0
# 3           20623.0  27.0
# 4          107000.0  27.0
# ...             ...   ...
# 4311         7724.0  26.0
# 4312        35518.0  26.0
# 4313        26586.0  26.0
# 4314        19880.0  25.0
# 4315        80371.0  25.0
#
# [4012 rows x 2 columns]

# %%
df_line = df_line.groupby('Age', axis=0).median()
df_line
# Out:
#       ConvertedComp
# Age
# 25.0        39920.0
# 26.0        43834.0
# 27.0        49620.0
# 28.0        51559.0
# 29.0        55674.0
# 30.0        56376.0

# %%
df_line.plot(kind='line')

plt.title('Average Compensation Based on Age Groups')
plt.ylabel('Converted Compensation (Annual USD')
plt.xlabel('Age')

plt.show()

# %%
# Visualizing comparison of data
#
# Line Chart¶
# Plot the median ConvertedComp for all ages from 45 to 60.
#
# 數據比較視覺化
# 折線圖
# 繪製 45 歲至 60 歲所有年齡層的 ConvertedComp 中位數。
#
# case 2
#

# %%
# QUERY = """
# SELECT ConvertedComp, Age
# FROM master
# """

QUERY = """
SELECT ConvertedComp, Age
FROM master
WHERE age <= 60 AND age >= 45
order by age
"""

df_line = pd.read_sql_query(QUERY,conn)

df_line.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ConvertedComp  561 non-null    float64
#  1   Age            599 non-null    float64
# dtypes: float64(2)
# memory usage: 9.5 KB

# %%
df_line.median()
# Out:
# ConvertedComp    100000.0
# Age                  49.0
# dtype: float64

# %%
df_line.describe()
# Out:
#        ConvertedComp         Age
# count   5.610000e+02  599.000000
# mean    1.876936e+05   49.460768
# std     3.387617e+05    3.688731
# min     0.000000e+00   45.000000
# 25%     6.627600e+04   46.000000
# 50%     1.000000e+05   49.000000
# 75%     1.400000e+05   52.000000
# max     2.000000e+06   60.000000

# %%
df_line.head()
# Out:
#    ConvertedComp   Age
# 0        72522.0  45.0
# 1        54876.0  45.0
# 2       185000.0  45.0
# 3       165000.0  45.0
# 4       130000.0  45.0

# %%
df_line.groupby('Age')['ConvertedComp'].median()
# Out:
# Age
# 45.0     90330.0
# 46.0     91593.0
# 47.0     91606.0
# 48.0    105750.0
# 49.0     85248.0
# 50.0     95000.0
# 51.0    100000.0
# 52.0    105500.0
# 53.0    100463.0
# 54.0    121000.0
# 55.0    119000.0
# 56.0     99530.5
# 57.0    117578.0
# 58.0    108000.0
# 59.0    110000.0
# 60.0    132287.5
# Name: ConvertedComp, dtype: float64

# %%
df = df_line

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame named 'df' with 'Age' and 'ConvertedComp' columns

# Filter data for ages 45 to 60
df_filtered = df[(df['Age'] >= 45) & (df['Age'] <= 60)]

# Group by age and calculate the median ConvertedComp
grouped_data = df_filtered.groupby('Age')['ConvertedComp'].median()

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(grouped_data.index, grouped_data.values)

# Customize the plot
plt.title('Median Converted Compensation by Age (45-60)')
plt.xlabel('Age')
plt.ylabel('Median Converted Compensation')
plt.grid(True)

plt.show()

# %%
# Bar Chart
#
# Create a horizontal bar chart using column MainBranch.
#
# 長條圖 
# 使用 MainBranch 欄位建立水平長條圖。

# %%
# your code goes here

QUERY = """
SELECT *
FROM DevType
"""
df_bar = pd.read_sql_query(QUERY,conn)

df_bar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35314 entries, 0 to 35313
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Respondent  35314 non-null  int64
#  1   DevType     35314 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 551.9+ KB

# %%
df_bar.head()
# Out:
#    Respondent                 DevType
# 0           4   Developer, full-stack
# 1           9  Database administrator
# 2           9     Developer, back-end
# 3           9    Developer, front-end
# 4           9   Developer, full-stack

# %%
df_bar = df_bar.groupby('DevType', axis=0).count()

df_bar.sort_values(["Respondent"], ascending=True, inplace=True)

# %%
# generate plot
df_bar.plot(kind='barh', figsize=(20, 5), color='steelblue')
plt.xlabel('Total')
plt.title('Total Respondent Based on Developer Type')

plt.show()

# %%
# Bar Chart
#
# Create a horizontal bar chart using column MainBranch.
#
# 長條圖 
# 使用 MainBranch 欄位建立水平長條圖。
# 
# case 2
#

# %%
# QUERY = """
# SELECT MainBranch
# FROM master
# group by MainBranch
#  """

QUERY = """
SELECT *
FROM master
"""

df_bar = pd.read_sql_query(QUERY,conn)

df_bar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           11398 non-null  int64
#  1   Respondent      11398 non-null  int64
#  2   MainBranch      11398 non-null  object
#  3   Hobbyist        11398 non-null  object
#  4   OpenSourcer     11398 non-null  object
#  5   OpenSource      11317 non-null  object
#  6   Employment      11398 non-null  object
#  7   Country         11398 non-null  object
#  8   Student         11347 non-null  object
#  9   EdLevel         11286 non-null  object
#  10  UndergradMajor  10661 non-null  object
#  11  OrgSize         11302 non-null  object
#  12  YearsCode       11389 non-null  object
#  13  Age1stCode      11385 non-null  object
#  14  YearsCodePro    11382 non-null  object
#  15  CareerSat       11398 non-null  object
#  16  JobSat          11397 non-null  object
# ...

# %%
df_bar.head()
# Out:
#    index  Respondent                      MainBranch Hobbyist  \
# 0      0           4  I am a developer by profession       No
# 1      1           9  I am a developer by profession      Yes
# 2      2          13  I am a developer by profession      Yes
# 3      3          16  I am a developer by profession      Yes
# 4      4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# ...

# %%
df_bar['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   10618
# I am not primarily a developer, but I write code sometimes as part of my work      780
# Name: MainBranch, dtype: int64

# %%
df = df_bar

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame named 'df' with a 'MainBranch' column

# Count the occurrences of each value in the 'MainBranch' column
branch_counts = df['MainBranch'].value_counts()

# Create a horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=branch_counts.values, y=branch_counts.index, orient='h')

# Customize the plot
plt.title('Distribution of Main Branches')
plt.xlabel('Count')
plt.ylabel('Main Branch')

plt.show()

# %%
conn.close()
